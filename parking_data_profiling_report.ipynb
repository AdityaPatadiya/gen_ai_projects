# %%
pip install ydata_profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=1e4f10883292784b380d514cd050bd6bd601b07b5a3e9817bf0c7a0e5ebb84ba
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
pip install pydantic-settings
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("Parking_Transactions.csv")

profile = ProfileReport(df, title="Dataset Profiling Report")
ProfileReport(df)
profile.to_file("parking_dataset_report.html")

print("Profile report has been generated and saved as dataset_report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile report has been generated and saved as dataset_report.html

# %%
import numpy as np
import pandas as pd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ID                   1048575 non-null  int64
#  1   Source               1048575 non-null  object
#  2   Duration in Minutes  1048575 non-null  float64
#  3   Start Time           1048575 non-null  object
#  4   End Time             1048575 non-null  object
#  5   Amount               1048575 non-null  float64
#  6   Kiosk ID             415023 non-null   float64
#  7   App Zone ID          633552 non-null   float64
#  8   App Zone Group       633552 non-null   object
#  9   Payment Method       1048575 non-null  object
#  10  Location Group       1048568 non-null  object
#  11  Last Updated         1048575 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 96.0+ MB
